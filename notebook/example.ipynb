# %%
import os

# %%
root_dir=os.getcwd()
path1=root_dir+'/goodfiles'
path2=root_dir+'/badfiles'
os.makedirs(path1,exist_ok=True)
os.makedirs(path2,exist_ok=True)

# %%
def check_file_format(self):

# %%
data_file_path=r"C:/Users/rajes/wafer_detection/Training_Batch_Files"
files=[file_name for file_name in os.listdir(data_file_path)]

# %%
files
# Out:
# ['Wafer12_20012.csv',
#  'Waferdefault_15010_130532.csv',
#  'Wafer_07012020_000000.csv',
#  'wafer_07012020_041011.csv',
#  'Wafer_07012020_223345.csv',
#  'Wafer_08012020_120000.csv',
#  'Wafer_10012020_131534.csv',
#  'Wafer_11012020_151432.csv',
#  'Wafer_12012020_111.csv',
#  'Wafer_12012020_111213.csv',
#  'wafer_13012020_090817.csv',
#  'Wafer_13012020_141000.csv',
#  'Wafer_14012020_113045.csv',
#  'Wafer_15010_130532.csv',
#  'Wafer_15012020_130532.csv',
#  'wafer_16012020_051629.csv',
#  'wafer_16012020_134553.csv',
#  'wafer_17012020_125434.csv',
#  'Wafer_18012020_121532.csv',
#  'Wafer_19012020_141432.csv',
#  'wafer_20012020_090819.csv',
#  'Wafer_20012020_135132.csv',
#  'wafer_20022020_090716.csv',
#  'wafer_21012020_080913.csv',
#  'Wafer_21012020_143634.csv',
#  'Wafer_22012020_173245.csv',
#  'wafer_22022020_041119.csv',
#  'wafer_23012020_011008.csv',
#  'wafer_23012020_041211.csv',
#  'Wafer_23012020_163456.csv',
#  'Wafer_24012020_150121.csv',
# ...

# %%
def segregate():
    import shutil
    import re
    list1=[]
    for file_name in files:
        file_name=file_name.split('.csv')[0]
        file_name=file_name.split('_')
        list1.append(file_name)
    for i in range(len(list1)):
        if len(list1[i])!=3:
            shutil.copy(data_file_path+'/'+files[i],bad_file_path+'/'+files[i])
            continue
            
        test1=re.fullmatch('wafer',list1[i][0]) 
        test2=re.fullmatch(r'\d+',list1[i][1])
        test3=re.fullmatch(r'\d+',list1[i][2])
        
        if test1:
            pass
        else:
            shutil.copy(data_file_path+'/'+files[i],bad_file_path+'/'+files[i])
            continue
        if test2:
            pass
        else:
            shutil.copy(data_file_path+'/'+files[i],bad_file_path+'/'+files[i]) 
            continue 
        if test3:
            pass
        else:
            shutil.copy(data_file_path+'/'+files[i],bad_file_path+'/'+files[i])
            continue
        shutil.copy(data_file_path+'/'+files[i],good_file_path+'/'+files[i])

# %%
list1
# Out:
# [['Wafer12', '20012'],
#  ['Waferdefault', '15010', '130532'],
#  ['Wafer', '07012020', '000000'],
#  ['wafer', '07012020', '041011'],
#  ['Wafer', '07012020', '223345'],
#  ['Wafer', '08012020', '120000'],
#  ['Wafer', '10012020', '131534'],
#  ['Wafer', '11012020', '151432'],
#  ['Wafer', '12012020', '111'],
#  ['Wafer', '12012020', '111213'],
#  ['wafer', '13012020', '090817'],
#  ['Wafer', '13012020', '141000'],
#  ['Wafer', '14012020', '113045'],
#  ['Wafer', '15010', '130532'],
#  ['Wafer', '15012020', '130532'],
#  ['wafer', '16012020', '051629'],
#  ['wafer', '16012020', '134553'],
#  ['wafer', '17012020', '125434'],
#  ['Wafer', '18012020', '121532'],
#  ['Wafer', '19012020', '141432'],
#  ['wafer', '20012020', '090819'],
#  ['Wafer', '20012020', '135132'],
#  ['wafer', '20022020', '090716'],
#  ['wafer', '21012020', '080913'],
#  ['Wafer', '21012020', '143634'],
#  ['Wafer', '22012020', '173245'],
#  ['wafer', '22022020', '041119'],
#  ['wafer', '23012020', '011008'],
# ...

# %%
files
# Out:
# ['Wafer12_20012.csv',
#  'Waferdefault_15010_130532.csv',
#  'Wafer_07012020_000000.csv',
#  'wafer_07012020_041011.csv',
#  'Wafer_07012020_223345.csv',
#  'Wafer_08012020_120000.csv',
#  'Wafer_10012020_131534.csv',
#  'Wafer_11012020_151432.csv',
#  'Wafer_12012020_111.csv',
#  'Wafer_12012020_111213.csv',
#  'wafer_13012020_090817.csv',
#  'Wafer_13012020_141000.csv',
#  'Wafer_14012020_113045.csv',
#  'Wafer_15010_130532.csv',
#  'Wafer_15012020_130532.csv',
#  'wafer_16012020_051629.csv',
#  'wafer_16012020_134553.csv',
#  'wafer_17012020_125434.csv',
#  'Wafer_18012020_121532.csv',
#  'Wafer_19012020_141432.csv',
#  'wafer_20012020_090819.csv',
#  'Wafer_20012020_135132.csv',
#  'wafer_20022020_090716.csv',
#  'wafer_21012020_080913.csv',
#  'Wafer_21012020_143634.csv',
#  'Wafer_22012020_173245.csv',
#  'wafer_22022020_041119.csv',
#  'wafer_23012020_011008.csv',
#  'wafer_23012020_041211.csv',
#  'Wafer_23012020_163456.csv',
#  'Wafer_24012020_150121.csv',
# ...

# %%
import re

# %%
l1=re.fullmatch('wafer',list1[1][0])
l2=re.fullmatch('\d+',list1[1][1])
l3=re.fullmatch('\d+',list1[1][2])
v=l1

# %%
v

# %%
help(shutil.copy)
# Out:
# Help on function copy in module shutil:
#
# copy(src, dst, *, follow_symlinks=True)
#     Copy data and mode bits ("cp src dst"). Return the file's destination.
#
#     The destination may be a directory.
#
#     If follow_symlinks is false, symlinks won't be followed. This
#     resembles GNU's "cp -P src dst".
#
#     If source and destination are the same file, a SameFileError will be
#     raised.

# %%
good_file_path=root_dir+'/goodfiles'
bad_file_path=root_dir+'/badfiles'

# %%
os.getcwd()
# Out:
# 'c:\\Users\\rajes\\wafer_detection\\notebook'

# %%
os.chdir('c:\\Users\\rajes\\wafer_detection')

# %%
os.getcwd()
# Out:
# 'c:\\Users\\rajes\\wafer_detection'

# %%
root_dir=os.getcwd()
path1=root_dir+'/goodfiles'
path2=root_dir+'/badfiles'
os.makedirs(path1,exist_ok=True)
os.makedirs(path2,exist_ok=True)

# %%
good_file_path=path1
bad_file_path=path2

# %%
segregate()

# %%
from logger import logging
# Out:
# Traceback (most recent call last):
#
#   File "c:\Users\rajes\wafer_detection\wafer\lib\site-packages\IPython\core\interactiveshell.py", line 3552, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "C:\Users\rajes\AppData\Local\Temp\ipykernel_880\1684183811.py", line 1, in <module>
#     from logger import logging
#
#   File "c:\Users\rajes\wafer_detection\logger\__init__.py", line 22
#     filemode=w
#            ^
# SyntaxError: invalid syntax

# %%
files1=[file_name for file_name in os.listdir(path1) ]

# %%
  list1=[]
  for file_name in files1:
        file_name=file_name.split('.csv')[0]
        file_name=file_name.split('_')
        list1.append(file_name)

# %%
len(list1)
# Out:
# 18

# %%
for i in list1:
    if len(i[1])==8 and len(i[2])==6:
        pass
    else:
        shutil.move(path1+'/'+files1[i],path2+'/'+files1[1])

# %%
 len(os.listdir(path1))
# Out:
# 18

# %%
import pandas as pd
list2=[]
files2=[file for file in os.listdir(path1)]
for path in files2:
    df1=pd.read_csv(path1+'/'+path)
    shape=df1.shape
    for i in df1:
        if df1[i].isna().sum()==shape[1]:
            df1.drop([i],axis=1,inplace=True)
        else:
            df1[i].fillna('NULL',inplace=True) 
    df1.to_csv(f'{path3}/{path}', index=False,encoding='utf-8')            
    list2.append(df1.isna().sum())

# %%
list2=[]
for path in files2:
    df1=pd.read_csv(path1+'/'+path)
    list2.append(df1.isna().sum())

# %%
list2
# Out:
# [Unnamed: 0    0
#  Sensor-1      1
#  Sensor-2      1
#  Sensor-3      0
#  Sensor-4      0
#               ..
#  Sensor-587    0
#  Sensor-588    0
#  Sensor-589    0
#  Sensor-590    0
#  Good/Bad      0
#  Length: 592, dtype: int64,
#  Unnamed: 0    0
#  Sensor-1      0
#  Sensor-2      0
#  Sensor-3      0
#  Sensor-4      0
#               ..
#  Sensor-587    0
#  Sensor-588    0
#  Sensor-589    0
#  Sensor-590    0
#  Good/Bad      0
#  Length: 592, dtype: int64,
#  Unnamed: 0    0
#  Sensor-1      0
#  Sensor-2      1
#  Sensor-3      0
#  Sensor-4      0
#               ..
#  Sensor-587    0
#  Sensor-588    0
#  Sensor-589    0
#  Sensor-590    0
#  Good/Bad      0
#  Length: 592, dtype: int64,
#  Unnamed: 0    0
#  Sensor-1      1
#  Sensor-2      1
#  Sensor-3      0
#  Sensor-4      0
#               ..
#  Sensor-586    0
#  Sensor-587    0
#  Sensor-588    0
#  Sensor-589    0
#  Sensor-590    0
#  Length: 591, dtype: int64,
#  Unnamed: 0    0
#  Sensor-1      0
# ...

# %%
print(f'{path1}/{path}')
# Out:
# c:\Users\rajes\wafer_detection/goodfiles/wafer_31012020_090811.csv

# %%
help(df1.to_csv)
# Out:
# Help on method to_csv in module pandas.core.generic:
#
# to_csv(path_or_buf: Union[str, pathlib.Path, IO[~AnyStr], NoneType] = None, sep: str = ',', na_rep: str = '', float_format: Union[str, NoneType] = None, columns: Union[Sequence[Union[Hashable, NoneType]], NoneType] = None, header: Union[bool, List[str]] = True, index: bool = True, index_label: Union[bool, str, Sequence[Union[Hashable, NoneType]], NoneType] = None, mode: str = 'w', encoding: Union[str, NoneType] = None, compression: Union[str, Mapping[str, str], NoneType] = 'infer', quoting: Union[int, NoneType] = None, quotechar: str = '"', line_terminator: Union[str, NoneType] = None, chunksize: Union[int, NoneType] = None, date_format: Union[str, NoneType] = None, doublequote: bool = True, escapechar: Union[str, NoneType] = None, decimal: Union[str, NoneType] = '.', errors: str = 'strict') -> Union[str, NoneType] method of pandas.core.frame.DataFrame instance
#     Write object to a comma-separated values (csv) file.
#
# ...

# %%
help(df1.drop)
# Out:
# Help on method drop in module pandas.core.frame:
#
# drop(labels=None, axis=0, index=None, columns=None, level=None, inplace=False, errors='raise') method of pandas.core.frame.DataFrame instance
#     Drop specified labels from rows or columns.
#
#     Remove rows or columns by specifying label names and corresponding
#     axis, or by specifying directly index or column names. When using a
#     multi-index, labels on different levels can be removed by specifying
#     the level.
#
#     Parameters
#     ----------
#     labels : single label or list-like
#         Index or column labels to drop.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         Whether to drop labels from the index (0 or 'index') or
#         columns (1 or 'columns').
#     index : single label or list-like
#         Alternative to specifying axis (``labels, axis=0``
#         is equivalent to ``index=labels``).
#     columns : single label or list-like
# ...

# %%
path3=root_dir+'/goodfile1'

# %%
os.makedirs(path3,exist_ok=True)

# %%
import pandas as pd
list2=[]
files2=[file for file in os.listdir(path1)]
for path in files2:
    df1=pd.read_csv(path3+'/'+path)
    shape=df1.shape
    for i in df1:
        if df1[i].isna().sum()==shape[1]:
            df1.drop([i],axis=1,inplace=True)
        else:
            df1[i].fillna('NULL',inplace=True) 
    df1.to_csv(f'{path3}/{path}', index=False,encoding='utf-8')            
    list2.append(df1.isna().sum()) 
shutil.rmtree(path1)

# %%
list2
# Out:
# [Unnamed: 0    0
#  Sensor-1      0
#  Sensor-2      0
#  Sensor-3      0
#  Sensor-4      0
#               ..
#  Sensor-587    0
#  Sensor-588    0
#  Sensor-589    0
#  Sensor-590    0
#  Good/Bad      0
#  Length: 592, dtype: int64,
#  Unnamed: 0    0
#  Sensor-1      0
#  Sensor-2      0
#  Sensor-3      0
#  Sensor-4      0
#               ..
#  Sensor-587    0
#  Sensor-588    0
#  Sensor-589    0
#  Sensor-590    0
#  Good/Bad      0
#  Length: 592, dtype: int64,
#  Unnamed: 0    0
#  Sensor-1      0
#  Sensor-2      0
#  Sensor-3      0
#  Sensor-4      0
#               ..
#  Sensor-587    0
#  Sensor-588    0
#  Sensor-589    0
#  Sensor-590    0
#  Good/Bad      0
#  Length: 592, dtype: int64,
#  Unnamed: 0    0
#  Sensor-1      0
#  Sensor-2      0
#  Sensor-3      0
#  Sensor-4      0
#               ..
#  Sensor-586    0
#  Sensor-587    0
#  Sensor-588    0
#  Sensor-589    0
#  Sensor-590    0
#  Length: 591, dtype: int64,
#  Unnamed: 0    0
#  Sensor-1      0
# ...

# %%
import json
with open("C:/Users/rajes/wafer_detection/schema_training.json",'r') as file4:
    gg=json.load(file4)

# %%
from data_validation import Validation

# %%
validobject=Validation()
column=validobject.schema_file['ColName']

# %%
import mysql.connector as con
conn=con.connect(host='localhost',user='root',password='rajesh3341@38')
r=conn.cursor()
r.execute("use training")

# %%
r.execute("""create table table1(
          col2 int 
         )""")

# %%
r.execute("show tables")

# %%
r.fetchall()[0][0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_880\4093227457.py in <module>
# ----> 1 r.fetchall()[0][0]
#
# IndexError: list index out of range

# %%
r.execute("drop table table1")

# %%
if len(tables) == 0:
    # Create the table if it does not exist
    create_table_query = f"CREATE TABLE file_name1 ("
    for col_name, data_type in column.items():
        create_table_query += f"{col_name} {data_type}, "
    create_table_query = create_table_query.rstrip(", ") + ")"
    r.execute(create_table_query)
else:
    # If the table exists, alter the table to add new columns
    for col_name, data_type in column.items():
        r.execute(f"ALTER TABLE file_name1 ADD COLUMN {col_name} {data_type}")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_880\1548913849.py in <module>
#       5         create_table_query += f"{col_name} {data_type}, "
#       6     create_table_query = create_table_query.rstrip(", ") + ")"
# ----> 7     r.execute(create_table_query)
#       8 else:
#       9     # If the table exists, alter the table to add new columns
#
# OperationalError: near "-": syntax error

# %%
r.execute("show tables")
no_of_tables=len(r.fetchall())

# %%
r.execute("describe filename")

# %%
r.fetchall()
# Out:
# [('Wafer', 'varchar(30)', 'YES', '', None, ''),
#  ('Sensor - 1', 'float', 'YES', '', None, ''),
#  ('Sensor - 2', 'float', 'YES', '', None, ''),
#  ('Sensor - 3', 'float', 'YES', '', None, ''),
#  ('Sensor - 4', 'float', 'YES', '', None, ''),
#  ('Sensor - 5', 'float', 'YES', '', None, ''),
#  ('Sensor - 6', 'float', 'YES', '', None, ''),
#  ('Sensor - 7', 'float', 'YES', '', None, ''),
#  ('Sensor - 8', 'float', 'YES', '', None, ''),
#  ('Sensor - 9', 'float', 'YES', '', None, ''),
#  ('Sensor - 10', 'float', 'YES', '', None, ''),
#  ('Sensor - 11', 'float', 'YES', '', None, ''),
#  ('Sensor - 12', 'float', 'YES', '', None, ''),
#  ('Sensor - 13', 'float', 'YES', '', None, ''),
#  ('Sensor - 14', 'float', 'YES', '', None, ''),
#  ('Sensor - 15', 'float', 'YES', '', None, ''),
#  ('Sensor - 16', 'float', 'YES', '', None, ''),
#  ('Sensor - 17', 'float', 'YES', '', None, ''),
#  ('Sensor - 18', 'float', 'YES', '', None, ''),
#  ('Sensor - 19', 'float', 'YES', '', None, ''),
# ...

# %%
r.execute("drop table filename")

# %%
files=[filename for filename in os.listdir(good_file_path)]
for i in files:
    df1=pd.read_csv(good_file_path+'/'+i)
    df1.to_sql(table_name, connect, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31660\3720954842.py in <module>
# ----> 1 files=[filename for filename in os.listdir(good_file_path)]
#       2 for i in files:
#       3     df1=pd.read_csv(good_file_path+'/'+i)
#       4     df1.to_sql(table_name, connect, if_exists='append', index=False)
#
# NameError: name 'os' is not defined

# %%
good_file_path=validobject.good_file_path

# %%
good_file_path
# Out:
# 'c:\\Users\\rajes\\wafer_detection/good_file_path1'

# %%
colu=validobject.schema_file['ColName']

# %%
list3=[]
for i in colu:
    list3.append(colu[i])

# %%
list3[0]='varchar(30)'

# %%
colu['Wafer']='varchar(30)'

# %%
colu
# Out:
# {'Wafer': 'varchar(30)',
#  'Sensor - 1': ' float',
#  'Sensor - 2': ' float',
#  'Sensor - 3': ' float',
#  'Sensor - 4': ' float',
#  'Sensor - 5': ' float',
#  'Sensor - 6': ' float',
#  'Sensor - 7': ' float',
#  'Sensor - 8': ' float',
#  'Sensor - 9': ' float',
#  'Sensor - 10': ' float',
#  'Sensor - 11': ' float',
#  'Sensor - 12': ' float',
#  'Sensor - 13': ' float',
#  'Sensor - 14': ' float',
#  'Sensor - 15': ' float',
#  'Sensor - 16': ' float',
#  'Sensor - 17': ' float',
#  'Sensor - 18': ' float',
#  'Sensor - 19': ' float',
#  'Sensor - 20': ' float',
#  'Sensor - 21': ' float',
#  'Sensor - 22': ' float',
#  'Sensor - 23': ' float',
#  'Sensor - 24': ' float',
#  'Sensor - 25': ' float',
#  'Sensor - 26': ' float',
#  'Sensor - 27': ' float',
#  'Sensor - 28': ' float',
#  'Sensor - 29': ' float',
#  'Sensor - 30': ' float',
#  'Sensor - 31': ' float',
#  'Sensor - 32': ' float',
#  'Sensor - 33': ' float',
#  'Sensor - 34': ' float',
#  'Sensor - 35': ' float',
# ...

# %%
import sqlite3

dbfile='training.db'
connect=sqlite3.connect(dbfile)

# %%
r=connect.cursor()

# %%
r.execute("SELECT name FROM sqlite_master WHERE type='table';")

# %%
r.fetchall()
# Out:
# []

# %%
import sqlite3

# Replace 'your_database_file.db' with the path to your SQLite database file
db_file = 'training.db'

# Create a connection to the database
connection = sqlite3.connect(db_file)

# Create a cursor to execute queries
cursor = connection.cursor()

# Replace 'filename1' with the desired table name
table_name = 'filename1'

# Dictionary containing column names and their data types
column = {
    'column1': 'INTEGER',
    'column2': 'TEXT',
    # Add more columns and data types as needed
}

# Check if the table exists
cursor.execute("SELECT name FROM sqlite_master WHERE type='table' AND name=?", (table_name,))
tables = cursor.fetchall()

if len(tables) == 0:
    # Create the table if it does not exist
    create_table_query = f"CREATE TABLE {table_name} ("
    for col_name, data_type in column.items():
        create_table_query += f"{col_name} {data_type}, "
    create_table_query = create_table_query.rstrip(", ") + ")"
    cursor.execute(create_table_query)
else:
    # If the table exists, alter the table to add new columns
    for col_name, data_type in column.items():
        cursor.execute(f"ALTER TABLE {table_name} ADD COLUMN {col_name} {data_type}")

# %%
connect.execute("drop table filename1")

# %%
pd.read_sql('first.sql',connect)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\Users\rajes\wafer_detection\wafer\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1680         try:
# -> 1681             cur.execute(*args, **kwargs)
#    1682             return cur
#
# OperationalError: near "first": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_880\1185884166.py in <module>
# ----> 1 pd.read_sql('first.sql',connect)
#
# c:\Users\rajes\wafer_detection\wafer\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     487             coerce_float=coerce_float,
#     488             parse_dates=parse_dates,
# --> 489             chunksize=chunksize,
# ...

# %%
sql_file='first.sql'
with open(sql_file,'r') as file:
    query=file.read()
    connect.executescript(query)
query1="select * from filename1"    
df2=pd.read_sql(query1,connect)
df2

# %%
df2.to_csv("input.csv")

# %%
import pandas as pd
ee=pd.read_csv("C:/Users/rajes/bioinfo.csv",encoding='unicode_escape' )

# %%
ee.rename
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31660\3750403969.py in <module>
# ----> 1 ee.columns[0]="fre"
#
# c:\Users\rajes\wafer_detection\wafer\lib\site-packages\pandas\core\indexes\base.py in __setitem__(self, key, value)
#    4082
#    4083     def __setitem__(self, key, value):
# -> 4084         raise TypeError("Index does not support mutable operations")
#    4085
#    4086     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %%
ee.rename(columns={'Unnamed: 0':'wafer'},inplace=True)
# Out:
# Help on method rename in module pandas.core.frame:
#
# rename(mapper=None, index=None, columns=None, axis=None, copy=True, inplace=False, level=None, errors='ignore') method of pandas.core.frame.DataFrame instance
#     Alter axes labels.
#
#     Function / dict values must be unique (1-to-1). Labels not contained in
#     a dict / Series will be left as-is. Extra labels listed don't throw an
#     error.
#
#     See the :ref:`user guide <basics.rename>` for more.
#
#     Parameters
#     ----------
#     mapper : dict-like or function
#         Dict-like or functions transformations to apply to
#         that axis' values. Use either ``mapper`` and ``axis`` to
#         specify the axis to target with ``mapper``, or ``index`` and
#         ``columns``.
#     index : dict-like or function
#         Alternative to specifying axis (``mapper, axis=0``
#         is equivalent to ``index=mapper``).
#     columns : dict-like or function
# ...

# %%
import pandas as pd

# %%
import os

# %%
os.getcwdb()
# Out:
# c:\Users\rajes\wafer_detection\wafer\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: The Windows bytes API has been deprecated, use Unicode filenames instead
#   """Entry point for launching an IPython kernel.
# b'c:\\Users\\rajes\\wafer_detection\\notebook'

# %%
os.chdir("c:\\Users\\rajes\\wafer_detection")

# %%
path="data_ingestion/input.csv"
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(path)

# %%
df.head()
# Out:
#    Unnamed: 0      Wafer  Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  \
# 0           0  Wafer-501   3076.81   2158.75  2208.2334  1517.0152    1.0980
# 1           1  Wafer-502   2951.62   2511.92  2253.5111  1397.5060    0.9660
# 2           2  Wafer-503   2930.42   2505.17  2235.0556  1302.6607    1.6347
# 3           3  Wafer-504   2997.28   2357.99  2141.0667  1236.5212    0.9698
# 4           4  Wafer-505   3025.10   2475.18  2235.0556  1302.6607    1.6347
#
#    Sensor-6  Sensor-7  Sensor-8  ...  Sensor-582  Sensor-583  Sensor-584  \
# 0     100.0  110.1900    0.1247  ...     64.2405      0.5016      0.0152
# 1     100.0  109.7611    0.1210  ...      0.0000      0.4953      0.0105
# 2     100.0  109.9856    0.1230  ...         NaN      0.4958      0.0111
# 3     100.0   98.3344    0.1238  ...         NaN      0.4962      0.0086
# 4     100.0  109.9856    0.1230  ...         NaN      0.4983      0.0159
#
# ...

# %%
x=df.iloc[:,2:-1]
y=df["Good/Bad"]

# %%
y
# Out:
# 0      -1.0
# 1      -1.0
# 2      -1.0
# 3      -1.0
# 4      -1.0
#        ...
# 3469   -1.0
# 3470   -1.0
# 3471   -1.0
# 3472   -1.0
# 3473   -1.0
# Name: Good/Bad, Length: 3474, dtype: float64

# %%
y.plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
x
# Out:
#       Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6  Sensor-7  \
# 0      3076.81   2158.75  2208.2334  1517.0152    1.0980     100.0  110.1900
# 1      2951.62   2511.92  2253.5111  1397.5060    0.9660     100.0  109.7611
# 2      2930.42   2505.17  2235.0556  1302.6607    1.6347     100.0  109.9856
# 3      2997.28   2357.99  2141.0667  1236.5212    0.9698     100.0   98.3344
# 4      3025.10   2475.18  2235.0556  1302.6607    1.6347     100.0  109.9856
# ...        ...       ...        ...        ...       ...       ...       ...
# 3469   3079.17   2405.56  2217.3777  1425.1041    1.7585     100.0  106.2556
# 3470   2911.37   2541.21  2207.8111  1202.4520    1.6219     100.0  108.7689
# 3471   3085.57   2364.78  2178.6889  1657.3518    1.6603     100.0  100.8022
# 3472   3053.49   2457.08  2172.5333  1351.9648    1.6377     100.0  103.8800
# 3473   3120.68   2396.40  2177.0222  1448.8499    1.5565     100.0  103.2567
#
# ...

# %%
help(plt.plot)
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args, scalex=True, scaley=True, data=None, **kwargs)
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], *, data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...

# %%
df=df.iloc[:,2:]

# %%
df.head()
Modified_dataframe=df

# %%
Modified_dataframe["distlib"] = pd.cut(
            Modified_dataframe["Good/Bad"],
            bins=[-1.0,1],
            labels=[1]
            )
train_strat_split=None
test_strat_split=None
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_index,test_index in split.split(Modified_dataframe, Modified_dataframe["distlib"]):
    train_strat_split = housing_data_frame.loc[train_index].drop(["distlib"],axis=1)
    test_strat_split = housing_data_frame.loc[test_index].drop(["distlib"],axis=1)
train_strat_split.to_csv('data_preprocessing/train.csv')
test_strat_split.to_csv('data_preprocessing/test.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31660\3668099500.py in <module>
#       7 test_strat_split=None
#       8 split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
# ----> 9 for train_index,test_index in split.split(Modified_dataframe, Modified_dataframe["distlib"]):
#      10     train_strat_split = housing_data_frame.loc[train_index].drop(["distlib"],axis=1)
#      11     test_strat_split = housing_data_frame.loc[test_index].drop(["distlib"],axis=1)
#
# c:\Users\rajes\wafer_detection\wafer\lib\site-packages\sklearn\model_selection\_split.py in split(self, X, y, groups)
#    2020         to an integer.
#    2021         """
# -> 2022         y = check_array(y, ensure_2d=False, dtype=None)
#    2023         return super().split(X, y, groups)
#    2024
#
# ...

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# %%
Modified_dataframe.isna().sum()
# Out:
# Sensor-1        14
# Sensor-2        16
# Sensor-3        28
# Sensor-4        28
# Sensor-5        28
#               ...
# Sensor-589       0
# Sensor-590       0
# Good/Bad       400
# distib        3296
# distlib       3296
# Length: 593, dtype: int64

# %%
# Out:
# array([-1.,  1., nan])

# %%
# Out:
#       Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6  Sensor-7  \
# 0      3076.81   2158.75  2208.2334  1517.0152    1.0980     100.0  110.1900
# 1      2951.62   2511.92  2253.5111  1397.5060    0.9660     100.0  109.7611
# 2      2930.42   2505.17  2235.0556  1302.6607    1.6347     100.0  109.9856
# 3      2997.28   2357.99  2141.0667  1236.5212    0.9698     100.0   98.3344
# 4      3025.10   2475.18  2235.0556  1302.6607    1.6347     100.0  109.9856
# ...        ...       ...        ...        ...       ...       ...       ...
# 3469   3079.17   2405.56  2217.3777  1425.1041    1.7585     100.0  106.2556
# 3470   2911.37   2541.21  2207.8111  1202.4520    1.6219     100.0  108.7689
# 3471   3085.57   2364.78  2178.6889  1657.3518    1.6603     100.0  100.8022
# 3472   3053.49   2457.08  2172.5333  1351.9648    1.6377     100.0  103.8800
# 3473   3120.68   2396.40  2177.0222  1448.8499    1.5565     100.0  103.2567
#
# ...

# %%
Modified_dataframe.drop(['distlib'],axis=1,inplace=True)

# %%
import statistics

# %%
import stat

# %%
from scipy.stats import iqr

# %%
iqr_df=Modified_dataframe.apply(iqr)

# %%
iqr_df
# Out:
# Sensor-1          NaN
# Sensor-2          NaN
# Sensor-3          NaN
# Sensor-4          NaN
# Sensor-5          NaN
#                ...
# Sensor-587     0.0142
# Sensor-588     0.0101
# Sensor-589     0.0031
# Sensor-590    70.1917
# Good/Bad          NaN
# Length: 591, dtype: float64

# %%
Modified_dataframe
# Out:
#       Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6  Sensor-7  \
# 0      3076.81   2158.75  2208.2334  1517.0152    1.0980     100.0  110.1900
# 1      2951.62   2511.92  2253.5111  1397.5060    0.9660     100.0  109.7611
# 2      2930.42   2505.17  2235.0556  1302.6607    1.6347     100.0  109.9856
# 3      2997.28   2357.99  2141.0667  1236.5212    0.9698     100.0   98.3344
# 4      3025.10   2475.18  2235.0556  1302.6607    1.6347     100.0  109.9856
# ...        ...       ...        ...        ...       ...       ...       ...
# 3469   3079.17   2405.56  2217.3777  1425.1041    1.7585     100.0  106.2556
# 3470   2911.37   2541.21  2207.8111  1202.4520    1.6219     100.0  108.7689
# 3471   3085.57   2364.78  2178.6889  1657.3518    1.6603     100.0  100.8022
# 3472   3053.49   2457.08  2172.5333  1351.9648    1.6377     100.0  103.8800
# 3473   3120.68   2396.40  2177.0222  1448.8499    1.5565     100.0  103.2567
#
# ...

# %%
from sklearn.impute import KNNImputer

# %%
imputer=KNNImputer()

# %%
help(KNNImputer)
# Out:
# Help on class KNNImputer in module sklearn.impute._knn:
#
# class KNNImputer(sklearn.impute._base._BaseImputer)
#  |  KNNImputer(*, missing_values=nan, n_neighbors=5, weights='uniform', metric='nan_euclidean', copy=True, add_indicator=False)
#  |
#  |  Imputation for completing missing values using k-Nearest Neighbors.
#  |
#  |  Each sample's missing values are imputed using the mean value from
#  |  `n_neighbors` nearest neighbors found in the training set. Two samples are
#  |  close if the features that neither is missing are close.
#  |
#  |  Read more in the :ref:`User Guide <knnimpute>`.
#  |
#  |  .. versionadded:: 0.22
#  |
#  |  Parameters
#  |  ----------
#  |  missing_values : int, float, str, np.nan or None, default=np.nan
#  |      The placeholder for the missing values. All occurrences of
#  |      `missing_values` will be imputed. For pandas' dataframes with
#  |      nullable integer dtypes with missing values, `missing_values`
# ...

# %%
null_checker=pd.DataFrame({
    'column_names':[],
    'no_of_null_values':[]
})

# %%
check=0
list1=[]
list2=[]
for i in Modified_dataframe:
    list1.append(i)
    list2.append(Modified_dataframe[i].isna().sum())
    if Modified_dataframe[i].isna().sum()>0:
        check=1
null_checker=pd.DataFrame({
    'column_names':list1,
    'no_of_null_values':list2
})

# %%
help(null_checker.append)
# Out:
# Help on method append in module pandas.core.frame:
#
# append(other, ignore_index=False, verify_integrity=False, sort=False) -> 'DataFrame' method of pandas.core.frame.DataFrame instance
#     Append rows of `other` to the end of caller, returning a new object.
#
#     Columns in `other` that are not in the caller are added as new columns.
#
#     Parameters
#     ----------
#     other : DataFrame or Series/dict-like object, or list of these
#         The data to append.
#     ignore_index : bool, default False
#         If True, the resulting axis will be labeled 0, 1, …, n - 1.
#     verify_integrity : bool, default False
#         If True, raise ValueError on creating index with duplicates.
#     sort : bool, default False
#         Sort columns if the columns of `self` and `other` are not aligned.
#
#         .. versionadded:: 0.23.0
#         .. versionchanged:: 1.0.0
#
#             Changed to not sort by default.
#
#     Returns
#     -------
#     DataFrame
#
#     See Also
# ...

# %%
null_checker
# Out:
#     column_names  no_of_null_values
# 0       Sensor-1                 14
# 1       Sensor-2                 16
# 2       Sensor-3                 28
# 3       Sensor-4                 28
# 4       Sensor-5                 28
# ..           ...                ...
# 586   Sensor-587                  0
# 587   Sensor-588                  0
# 588   Sensor-589                  0
# 589   Sensor-590                  0
# 590     Good/Bad                400
#
# [591 rows x 2 columns]

# %%
import numpy as np
columns=Modified_dataframe.columns
knn_imputer=KNNImputer(n_neighbors=3,weights='uniform',missing_values=np.nan)
nd_arrray=knn_imputer.fit_transform(Modified_dataframe)
dataframe1=pd.DataFrame(nd_arrray,columns=columns)

# %%
dataframe1
# Out:
#       Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6  Sensor-7  \
# 0      3076.81   2158.75  2208.2334  1517.0152    1.0980     100.0  110.1900
# 1      2951.62   2511.92  2253.5111  1397.5060    0.9660     100.0  109.7611
# 2      2930.42   2505.17  2235.0556  1302.6607    1.6347     100.0  109.9856
# 3      2997.28   2357.99  2141.0667  1236.5212    0.9698     100.0   98.3344
# 4      3025.10   2475.18  2235.0556  1302.6607    1.6347     100.0  109.9856
# ...        ...       ...        ...        ...       ...       ...       ...
# 3469   3079.17   2405.56  2217.3777  1425.1041    1.7585     100.0  106.2556
# 3470   2911.37   2541.21  2207.8111  1202.4520    1.6219     100.0  108.7689
# 3471   3085.57   2364.78  2178.6889  1657.3518    1.6603     100.0  100.8022
# 3472   3053.49   2457.08  2172.5333  1351.9648    1.6377     100.0  103.8800
# 3473   3120.68   2396.40  2177.0222  1448.8499    1.5565     100.0  103.2567
#
# ...

# %%
import dill
with open('imputer.pkl','wb') as file:
    dill.dump(knn_imputer,file)

# %%
iqrdf1=dataframe1.apply(iqr)

# %%
iqrdf1
# Out:
# Sensor-1       89.5100
# Sensor-2       86.7000
# Sensor-3       37.1667
# Sensor-4      511.3839
# Sensor-5        0.4927
#                 ...
# Sensor-587      0.0142
# Sensor-588      0.0101
# Sensor-589      0.0031
# Sensor-590     70.1917
# Good/Bad        0.0000
# Length: 591, dtype: float64

# %%
list1=[]
for i in dataframe1:
    list2=list(dataframe1[i])
    list2.sort()
    length=len(list2)
    q1=int(np.ceil(length/4))
    lower_range=list2[q1]-(iqrdf1[i]*1.5)
    q3=int(np.ceil((3*length)/4))
    higher_range=list2[q3]+(iqrdf1[i]*1.5)
    range=(lower_range,higher_range)
    list1.append(range)

# %%
list1
# Out:
# [(2833.715, 3191.825),
#  (2321.7700000000004, 2668.6099999999997),
#  (2124.9499499999993, 2273.61675),
#  (311.71015, 2357.24575),
#  (0.2812499999999998, 2.2520500000000006),
#  (100.0, 100.0),
#  (88.14120000000001, 114.98879999999997),
#  (0.1169, 0.1281),
#  (1.2589000000000001, 1.6646999999999998),
#  (-0.03875000000000001, 0.035350000000000006),
#  (-0.022899999999999997, 0.0235),
#  (0.9379999999999998, 0.9916000000000001),
#  (192.34044999999998, 207.86225000000002),
#  (0.0, 0.0),
#  (1.4598999999999984, 16.667),
#  (386.67330000000004, 438.54380000000003),
#  (8.653949999999998, 11.018650000000001),
#  (0.9555000000000001, 0.9898999999999999),
#  (182.51034999999996, 198.09045000000003),
#  (12.332650000000001, 12.672249999999998),
#  (1.3691, 1.4426999999999999),
#  (-7218.5, -4251.75),
#  (2139.125, 3324.125),
#  (-5891.5, -1823.5),
#  (-5698.25, 5661.75),
#  (0.7498, 1.637),
#  (1.7551999999999999, 2.1512),
#  (2.0821999999999994, 10.475000000000001),
# ...

# %%
count=0
for i in dataframe1:
    list3=[]
    df2=dataframe1[(dataframe1[i]<list1[count][0]) | (dataframe1[i]>list1[count][1])]
    list3=list(df2.index)
    dataframe1.drop(list3,axis=0,inplace=True)
    count=count+1

# %%
df2=dataframe1[(dataframe1['Sensor-6']<list1[5][0]) | (dataframe1['Sensor-6']>list1[5][1])]

# %%
dataframe1.drop(list(df2.index),axis=0,inplace=True)

# %%
dataframe1['Sensor-1'].plot(kind='boxplot')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31660\3290949733.py in <module>
# ----> 1 dataframe1['Sensor-1'].plot(kind='boxplot',vert=false)
#
# NameError: name 'false' is not defined

# %%
plt.boxplot(dataframe1['Sensor-1'],vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2522be07ef0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2522be07e80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2522be2a160>],
#  'medians': [<matplotlib.lines.Line2D at 0x2522be36da0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2522be2abe0>],
#  'means': []}

# %%
df2
# Out:
# Empty DataFrame
# ...

# %%
dataframe1
# Out:
#       Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6  Sensor-7  \
# 414    2996.90   2448.07  2162.7556  1041.1557    0.8479     100.0  107.2622
# 924    2980.11   2516.33  2201.8222  1288.0857    1.6769     100.0   95.9789
# 1350   2996.90   2448.07  2162.7556  1041.1557    0.8479     100.0  107.2622
# 2151   2996.90   2448.07  2162.7556  1041.1557    0.8479     100.0  107.2622
# 2661   2980.11   2516.33  2201.8222  1288.0857    1.6769     100.0   95.9789
# 3087   2996.90   2448.07  2162.7556  1041.1557    0.8479     100.0  107.2622
#
#       Sensor-8  Sensor-9  Sensor-10  ...  Sensor-582  Sensor-583  Sensor-584  \
# 414     0.1221    1.4446    -0.0016  ...     50.5380      0.5039      0.0169
# 924     0.1209    1.4805    -0.0073  ...     63.2615      0.4956      0.0104
# 1350    0.1221    1.4446    -0.0016  ...     50.5380      0.5039      0.0169
# 2151    0.1221    1.4446    -0.0016  ...     50.5380      0.5039      0.0169
# ...

# %%
list1=dataframe1.describe().iloc[3,:]==0.0

# %%
std_values.
# Out:
# Index(['Sensor-1', 'Sensor-2', 'Sensor-3', 'Sensor-4', 'Sensor-5', 'Sensor-6',
#        'Sensor-7', 'Sensor-8', 'Sensor-9', 'Sensor-10',
#        ...
#        'Sensor-582', 'Sensor-583', 'Sensor-584', 'Sensor-585', 'Sensor-586',
#        'Sensor-587', 'Sensor-588', 'Sensor-589', 'Sensor-590', 'Good/Bad'],
#       dtype='object', length=591)

# %%
value_to_find = 2743.2399999999993
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\rajes\wafer_detection\wafer\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'column_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
std_values=dict(std_values)

# %%
std_values
# Out:
# {'Sensor-1': 2743.2399999999993,
#  'Sensor-2': 2158.75,
#  'Sensor-3': 2060.66,
#  'Sensor-4': 0.0,
#  'Sensor-5': 0.6815,
#  'Sensor-6': 100.0,
#  'Sensor-7': 82.1311,
#  'Sensor-8': 0.0,
#  'Sensor-9': 1.1909999999999998,
#  'Sensor-10': -0.0534,
#  'Sensor-11': -0.0349,
#  'Sensor-12': 0.6554,
#  'Sensor-13': 182.09400000000002,
#  'Sensor-14': 0.0,
#  'Sensor-15': 2.2935,
#  'Sensor-16': 333.4486,
#  'Sensor-17': 4.4696,
#  'Sensor-18': 0.5794,
#  'Sensor-19': 169.1774,
#  'Sensor-20': 9.8773,
#  'Sensor-21': 1.1797,
#  'Sensor-22': -7150.25,
#  'Sensor-23': 0.0,
#  'Sensor-24': -9986.750000000002,
#  'Sensor-25': -14804.5,
#  'Sensor-26': 0.0,
#  'Sensor-27': 0.0,
#  'Sensor-28': 0.0,
#  'Sensor-29': 59.4,
#  'Sensor-30': 0.6667,
#  'Sensor-31': 0.034099999999999984,
#  'Sensor-32': 2.0698,
#  'Sensor-33': 83.1829,
#  'Sensor-34': 7.6032,
#  'Sensor-35': 49.8348,
#  'Sensor-36': 63.6774,
#  'Sensor-37': 40.2289,
#  'Sensor-38': 64.9193,
#  'Sensor-39': 85.1414,
# ...

# %%
len(list2)
# Out:
# 187

# %%
count=0
for i in list1:
    if i==True:
        count=count+1

# %%
count
# Out:
# 187

# %%
list1=[]
std_values=dataframe1.describe().iloc[3,:]
std_values=dict(std_values)
for i in std_values:
    if std_values[i]==0.0:
        list1.append(i)

# %%
list1
# Out:
# ['Sensor-4',
#  'Sensor-8',
#  'Sensor-14',
#  'Sensor-23',
#  'Sensor-26',
#  'Sensor-27',
#  'Sensor-28',
#  'Sensor-53',
#  'Sensor-75',
#  'Sensor-98',
#  'Sensor-113',
#  'Sensor-115',
#  'Sensor-129',
#  'Sensor-140',
#  'Sensor-142',
#  'Sensor-144',
#  'Sensor-150',
#  'Sensor-160',
#  'Sensor-161',
#  'Sensor-162',
#  'Sensor-163',
#  'Sensor-164',
#  'Sensor-165',
#  'Sensor-166',
#  'Sensor-179',
#  'Sensor-180',
#  'Sensor-187',
#  'Sensor-190',
#  'Sensor-191',
#  'Sensor-192',
#  'Sensor-193',
#  'Sensor-194',
#  'Sensor-195',
#  'Sensor-202',
#  'Sensor-203',
#  'Sensor-207',
#  'Sensor-210',
#  'Sensor-227',
#  'Sensor-230',
#  'Sensor-231',
#  'Sensor-232',
#  'Sensor-233',
#  'Sensor-234',
#  'Sensor-235',
#  'Sensor-236',
#  'Sensor-237',
#  'Sensor-238',
#  'Sensor-241',
#  'Sensor-242',
#  'Sensor-243',
#  'Sensor-244',
#  'Sensor-248',
#  'Sensor-250',
#  'Sensor-257',
#  'Sensor-258',
#  'Sensor-259',
#  'Sensor-260',
#  'Sensor-261',
#  'Sensor-262',
# ...

# %%
dataframe1['Good/Bad'].unique()
# Out:
# array([-1.        ,  1.        , -0.33333333,  0.33333333])

# %%
class_distribution = dataframe1['Good/Bad'].value_counts()

# Calculate the class percentage
class_percentage = dataframe1['Good/Bad'].value_counts(normalize=True) * 100

# Calculate the class ratio
class_ratio = len(dataframe1['Good/Bad'][y == -1.0]) / len(dataframe1['Good/Bad'][y == 1.0])

# Calculate the imbalance ratio
imbalance_ratio = len(dataframe1['Good/Bad'][y == 1.0]) / len(dataframe1['Good/Bad'][y == -1.0])

# %%
imbalance_ratio
# Out:
# 0.06146408839779006

# %%
class_ratio
# Out:
# 16.269662921348313

# %%
from sklearn.cluster import KMeans
from data_preprocessing  import preprocessing
pre=preprocessing()
input_features=pre.input_features

# %%
from sklearn.cluster import KMeans

# %%
from  data_preprocessing  import preprocessing

# %%
wcss=[]
v=15
for i in range(v):
    pass
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31660\114662826.py in <module>
#       1 wcss=[]
#       2 v=15
# ----> 3 for i in range(v):
#       4     pass
#       5
#
# TypeError: 'tuple' object is not callable

# %%
help(plt.savefig)
# Out:
# Help on function savefig in module matplotlib.pyplot:
#
# savefig(*args, **kwargs)
#     Save the current figure.
#
#     Call signature::
#
#       savefig(fname, *, dpi='figure', format=None, metadata=None,
#               bbox_inches=None, pad_inches=0.1,
#               facecolor='auto', edgecolor='auto',
#               backend=None, **kwargs
#              )
#
#     The available output formats depend on the backend being used.
#
#     Parameters
#     ----------
#     fname : str or path-like or binary file-like
#         A path, or a Python file-like object, or
#         possibly some backend-dependent object such as
#         `matplotlib.backends.backend_pdf.PdfPages`.
#
#         If *format* is set, it determines the output format, and the file
#         is saved as *fname*.  Note that *fname* is used verbatim, and there
#         is no attempt to make the extension, if any, of *fname* match
#         *format*, and no extension is appended.
#
# ...

# %%
input_features
# Out:
#       Sensor-1  Sensor-2   Sensor-3  Sensor-5  Sensor-6  Sensor-7  Sensor-9  \
# 0      3076.81   2158.75  2208.2334    1.0980     100.0  110.1900    1.4357
# 1      2951.62   2511.92  2253.5111    0.9660     100.0  109.7611    1.5527
# 2      2930.42   2505.17  2235.0556    1.6347     100.0  109.9856    1.4588
# 3      2997.28   2357.99  2141.0667    0.9698     100.0   98.3344    1.5973
# 4      3025.10   2475.18  2235.0556    1.6347     100.0  109.9856    1.5525
# ...        ...       ...        ...       ...       ...       ...       ...
# 3469   3079.17   2405.56  2217.3777    1.7585     100.0  106.2556    1.4794
# 3470   2911.37   2541.21  2207.8111    1.6219     100.0  108.7689    1.5322
# 3471   3085.57   2364.78  2178.6889    1.6603     100.0  100.8022    1.4945
# 3472   3053.49   2457.08  2172.5333    1.6377     100.0  103.8800    1.5680
# 3473   3120.68   2396.40  2177.0222    1.5565     100.0  103.2567    1.4920
#
# ...

# %%
plt.plot(range(1,15),wcss)
plt.xlabel("no.of centriods")
plt.ylabel("wcss")
plt.savefig('Elbowplot.png')
